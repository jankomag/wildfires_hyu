# %%
# %load_ext jupyternotify

# %%
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
from datetime import datetime

from sklearn import preprocessing
from sklearn import metrics
import sklearn.metrics
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import Normalizer
from sklearn.model_selection import cross_val_score

from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import GridSearchCV
from sklearn.inspection import plot_partial_dependence
from xgboost import XGBRegressor

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Normalization
from tensorflow.keras import regularizers
import tensorflow.keras as keras
from keras.callbacks import ModelCheckpoint
from tensorflow.keras import regularizers

# %% [markdown]
# # Data wrangling

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('Wildfire.csv')
df = df.drop(columns=['Unnamed: 0', 'Unnamed: 0.1', 'fire_name','disc_date_final','cont_date_final','cont_clean_date','putout_time'])
df['disc_clean_date'] = pd.to_datetime(df['disc_clean_date'], format='%m/%d/%Y')
df.columns
# Out:
# Index(['fire_size', 'fire_size_class', 'stat_cause_descr', 'latitude',
#        'longitude', 'state', 'disc_clean_date', 'discovery_month',
#        'disc_date_pre', 'disc_pre_year', 'disc_pre_month', 'wstation_usaf',
#        'dstation_m', 'wstation_wban', 'wstation_byear', 'wstation_eyear',
#        'Vegetation', 'fire_mag', 'weather_file', 'Temp_pre_30', 'Temp_pre_15',
#        'Temp_pre_7', 'Temp_cont', 'Wind_pre_30', 'Wind_pre_15', 'Wind_pre_7',
#        'Wind_cont', 'Hum_pre_30', 'Hum_pre_15', 'Hum_pre_7', 'Hum_cont',
#        'Prec_pre_30', 'Prec_pre_15', 'Prec_pre_7', 'Prec_cont', 'remoteness'],
#       dtype='object')

# %%
#one hot encoding vegetation
df['Vegetation'] = df['Vegetation'].astype('category')
df['Cause'] = df['stat_cause_descr'].astype('category')

df = pd.get_dummies(df,prefix=['Vegetation'], columns = ['Vegetation'], drop_first=True)
df = pd.get_dummies(df,prefix=['Cause'], columns = ['stat_cause_descr'], drop_first=True)

# %%
df_numerics_only = df.select_dtypes(include=np.number)

corr = df_numerics_only.corr()
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(220, 20, n=200),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);
sns.set(rc={'figure.figsize':(15,16)})

# %%
#sns.pairplot(df[['latitude', 'fire_size', 'Hum_cont','Hum_pre_7', 'Hum_pre_15','Temp_pre_15', 'Temp_cont']], diag_kind='kde')

# %%
### Dealing with missing data
print(len(df))

# drop columns where weather file is missing
index = df[df['weather_file'] == 'File Not Found'].index
df.drop(index, inplace = True)
print(len(df))
# Out:
# 55367
# 41132

# %%
# Weather data has a lot of 0 and values some of which may be missing values
# Mark '0' values in weather columns as Na (to see how many there are)
subset0 = ['Temp_pre_30','Temp_pre_15','Temp_pre_7','Temp_cont','Wind_pre_30','Wind_pre_15','Wind_pre_7','Wind_cont','Hum_pre_30', 'Hum_pre_15','Hum_pre_7','Hum_cont']
df[subset0] = df[subset0].replace({0:np.nan, '0':np.nan})
print(len(df))

# Mark '-1' as missing
subset_neg1 = ['Temp_pre_30','Temp_pre_15','Temp_pre_7','Temp_cont','Wind_pre_30','Wind_pre_15','Wind_pre_7','Wind_cont','Hum_pre_30', 'Hum_pre_15','Hum_pre_7','Hum_cont','Prec_pre_30','Prec_pre_15','Prec_pre_7','Prec_cont']
df[subset_neg1] = df[subset_neg1].replace({-1:np.nan})
print(len(df))

# Drop observations where all weather columns are 0
df = df.dropna(how='all',
                    subset=['Temp_pre_30','Temp_pre_15','Temp_pre_7','Temp_cont','Wind_pre_30','Wind_pre_15','Wind_pre_7','Wind_cont',])
print(len(df))
# This leaves us with 38,689 observations to work with (originally we had 50,000)
#print(" \nCount total NaN at each column in a DataFrame : \n\n",
#      df.isnull().sum())
msno.matrix(df)
# Out:
# 41132
# 41132
# 38689
# <AxesSubplot:>

# %%
# fill the 'pre' columns temp wind and humidity with mean values
subset_fill_mean = ['Temp_pre_30','Temp_pre_15','Temp_pre_7', 'Wind_pre_30','Wind_pre_15','Wind_pre_7', 'Hum_pre_30', 'Hum_pre_15','Hum_pre_7']
df[subset_fill_mean] = df[subset_fill_mean].fillna(df[subset_fill_mean].mean())

# Fill NAs in the date of fire containment based on mean values from previous days
for col in ['Temp','Wind','Hum']:
    df[f'{col}_cont'] = df.apply(
        lambda row: (row[f'{col}_pre_7']+row[f'{col}_pre_15']+row[f'{col}_pre_30'])/3 if np.isnan(row[f'{col}_cont']) else row[f'{col}_cont'],
        axis=1)

# %% [markdown]
# ## Experiment data preparation

# %% [markdown]
# ### Experiment 1
# Including all the available variables in the model

# %%
# selecting features and target variables
X1 = df[['Vegetation_4','Vegetation_9','Vegetation_12','Vegetation_14','Vegetation_15','Vegetation_16','latitude','Temp_pre_30','Temp_pre_15','Temp_pre_7','Temp_cont','Wind_pre_30','Wind_pre_15','Wind_pre_7','Wind_cont','Hum_pre_30', 'Hum_pre_15','Hum_pre_7','Hum_cont','Prec_pre_30','Prec_pre_15','Prec_pre_7','Prec_cont','Cause_Debris Burning','Cause_Equipment Use','Cause_Fireworks','Cause_Lightning','Cause_Miscellaneous','Cause_Missing/Undefined','Cause_Powerline','Cause_Railroad','Cause_Smoking','Cause_Structure', 'longitude']]
y = df['fire_size']

#X_norm = (X-X.min())/(X.max()-X.min())
#y_norm = (y-y.min())/(y.max()-y.min())

#train test split
X1_train, X1_test, y_train, y_test = train_test_split(X1, y, test_size=0.2, random_state=42)
df1 = [X1_train, X1_test, y_train, y_test]

# %% [markdown]
# ### Experiment 2
# Include only weather, without cont

# %%
# selecting features and target variables
X2 = df[['Vegetation_4','Vegetation_9','Vegetation_12','Vegetation_14','Vegetation_15','Vegetation_16','latitude','Temp_pre_30','Temp_pre_15','Temp_pre_7','Wind_pre_30','Wind_pre_15','Wind_pre_7','Hum_pre_30', 'Hum_pre_15','Hum_pre_7','Prec_pre_30','Prec_pre_15','Prec_pre_7','Cause_Debris Burning','Cause_Equipment Use','Cause_Fireworks','Cause_Lightning','Cause_Miscellaneous','Cause_Missing/Undefined','Cause_Powerline','Cause_Railroad','Cause_Smoking','Cause_Structure', 'longitude']]
y = df['fire_size']

#X_norm = (X-X.min())/(X.max()-X.min())
#y_norm = (y-y.min())/(y.max()-y.min())

#train test split
X2_train, X2_test, y_train, y_test = train_test_split(X2, y, test_size=0.2, random_state=42)
df2 = [X2_train, X2_test, y_train, y_test]

# %% [markdown]
# ### Experiment 3

# %%
# selecting features and target variables
df_3 = df[['fire_size','latitude','Temp_pre_30','Temp_pre_15','Temp_pre_7','Wind_pre_30','Wind_pre_15','Wind_pre_7','Hum_pre_30', 'Hum_pre_15','Hum_pre_7','Prec_pre_30','Prec_pre_15','Prec_pre_7','longitude']]
names = df_3.columns
df_3 = preprocessing.normalize(df_3)
scaled_df = pd.DataFrame(df_3, columns=names)

X3 = scaled_df[['latitude','Temp_pre_30','Temp_pre_15','Temp_pre_7','Wind_pre_30','Wind_pre_15','Wind_pre_7','Hum_pre_30', 'Hum_pre_15','Hum_pre_7','Prec_pre_30','Prec_pre_15','Prec_pre_7','longitude']]
y = scaled_df['fire_size']

#train test split
X3_train, X3_test, y_train, y_test = train_test_split(X3, y, test_size=0.2, random_state=42)
df3 = [X3_train, X3_test, y_train, y_test]

# %% [markdown]
# ### Experiment 4
# Like exp 3 but without normalization

# %%
# selecting features and target variables
X4 = df[['latitude','Temp_pre_30','Temp_pre_15','Temp_pre_7','Wind_pre_30','Wind_pre_15','Wind_pre_7','Hum_pre_30', 'Hum_pre_15','Hum_pre_7','Prec_pre_30','Prec_pre_15','Prec_pre_7','longitude']]
y = df['fire_size']

#train test split
X4_train, X4_test, y_train, y_test = train_test_split(X4, y, test_size=0.2, random_state=42)
df4 = [X4_train, X4_test, y_train, y_test]

# %% [markdown]
# # Modelling
# ### Decision Tree

# %%
# Deccision trees
dectr = DecisionTreeRegressor(random_state=0)
dectr.fit(df1[0], df1[2])

predictions = dectr.predict(df1[1])
print('Mean Absolute Error:', metrics.mean_absolute_error(df1[3], predictions))
print('R Squared:', metrics.r2_score(df1[3], predictions))
# Out:
# Mean Absolute Error: 3268.2669224463684
# R Squared: -0.4225369622179067

# %% [markdown]
# ### Gradient Boosting

# %%
gr_boost = GradientBoostingRegressor()
gr_boost.fit(X_train, y_train)

predictions = gr_boost.predict(X_test)
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, predictions))
print('R Squared:', metrics.r2_score(y_test, predictions))
# Out:
# Mean Absolute Error: 3049.1827127357346
# R Squared: 0.07052621325864428

# %% [markdown]
# ### XGBoost

# %%
XGBModel = XGBRegressor(n_estimators=10)
XGBModel.fit(X_train, y_train, verbose=True)

# Get the mean absolute error on the validation data :
XGBpredictions = XGBModel.predict(X_test)
MAE = metrics.mean_absolute_error(y_test , XGBpredictions)
print('XGBoost validation MAE = ',MAE)
print('R Squared:', metrics.r2_score(y_test, XGBpredictions))
# Out:
# XGBoost validation MAE =  2937.658897492385
# R Squared: 0.10415435147180219

# %% [markdown]
# ### All

# %%
for model in [DecisionTreeRegressor(), GradientBoostingRegressor(), RandomForestRegressor(), XGBRegressor()]:
    for idx,df in enumerate([df1, df2, df3, df4]):
        model.fit(df[0], df[2])
        print(f'{model}; Experiment {idx+1}; Mean Absolute Error:', metrics.mean_absolute_error(df[3], model.predict(df[1])))
        print(f'{model}; Experiment {idx+1}; R Squared:', metrics.r2_score(df[3], model.predict(df[1])))
        print('')
# Out:
# DecisionTreeRegressor(); Experiment 1; Mean Absolute Error: 3494.9741464616177
# DecisionTreeRegressor(); Experiment 1; R Squared: -0.7565739405825933
#
# DecisionTreeRegressor(); Experiment 2; Mean Absolute Error: 3162.7536240410955
# DecisionTreeRegressor(); Experiment 2; R Squared: -0.27322741749561863
#
# DecisionTreeRegressor(); Experiment 3; Mean Absolute Error: 0.03842191604679278
# DecisionTreeRegressor(); Experiment 3; R Squared: 0.957108215018912
#
# DecisionTreeRegressor(); Experiment 4; Mean Absolute Error: 3345.006506254846
# DecisionTreeRegressor(); Experiment 4; R Squared: -0.419045009760981
#
# GradientBoostingRegressor(); Experiment 1; Mean Absolute Error: 3063.4525913067396
# GradientBoostingRegressor(); Experiment 1; R Squared: 0.06244505132019751
#
# GradientBoostingRegressor(); Experiment 2; Mean Absolute Error: 3037.274286490015
# GradientBoostingRegressor(); Experiment 2; R Squared: 0.10981113663525455
#
# GradientBoostingRegressor(); Experiment 3; Mean Absolute Error: 0.047406076182096156
# GradientBoostingRegressor(); Experiment 3; R Squared: 0.9542919612901529
#
# GradientBoostingRegressor(); Experiment 4; Mean Absolute Error: 3099.7984179610216
# GradientBoostingRegressor(); Experiment 4; R Squared: 0.10176523647699076
#
# RandomForestRegressor(); Experiment 1; Mean Absolute Error: 2955.8418571504826
# RandomForestRegressor(); Experiment 1; R Squared: 0.16486877975260372
#
# RandomForestRegressor(); Experiment 2; Mean Absolute Error: 2981.763873982183
# RandomForestRegressor(); Experiment 2; R Squared: 0.16652582277905403
#
# RandomForestRegressor(); Experiment 3; Mean Absolute Error: 0.031517273272494185
# RandomForestRegressor(); Experiment 3; R Squared: 0.9794674416519624
#
# RandomForestRegressor(); Experiment 4; Mean Absolute Error: 3052.002154392577
# RandomForestRegressor(); Experiment 4; R Squared: 0.1652524743881152
#
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.300000012,
#              max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=100, n_jobs=4,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None); Experiment 1; Mean Absolute Error: 3057.4868148375426
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.300000012,
#              max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=100, n_jobs=4,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None); Experiment 1; R Squared: 0.06123173933870685
#
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.300000012,
#              max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=100, n_jobs=4,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None); Experiment 2; Mean Absolute Error: 3016.593035087013
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.300000012,
#              max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=100, n_jobs=4,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None); Experiment 2; R Squared: 0.09719749746211581
#
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.300000012,
#              max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=100, n_jobs=4,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None); Experiment 3; Mean Absolute Error: 0.028285746080932428
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.300000012,
#              max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=100, n_jobs=4,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None); Experiment 3; R Squared: 0.9835797601172495
#
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.300000012,
#              max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=100, n_jobs=4,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None); Experiment 4; Mean Absolute Error: 3182.9244793532735
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.300000012,
#              max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=100, n_jobs=4,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None); Experiment 4; R Squared: 0.040811465990340245

# %% [markdown]
# ### Random Forest

# %%
# Random Forest Regressor 
rf_reg = RandomForestRegressor(n_estimators = 250, max_depth=10)

# fit the regressor with x and y data
rf_reg.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=10, n_estimators=250)

# %%
predictions = rf_reg.predict(X_test)
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, predictions))
print('R Squared:', metrics.r2_score(y_test, predictions))
# Out:
# Mean Absolute Error: 2895.7761927316797
# R Squared: 0.13366735067739555

# %%
features = [6, 10, 18, 17, 9, 'Temp_pre_15', 'Temp_pre_30', 'Hum_pre_30','Hum_pre_15']
plot_partial_dependence(rf_reg, X_train, features)

# %% [markdown]
# ### Hyper-parameter tuning
# Performing Grid Search
# Testing the model with different values for parameters like the number of estimators and maximum depth, and then selects the parametres that produce the best results.
#
# The basemodel of Random Forest Regressor produced the best results, so that is the algorithm we will tune.

# %%
# Shwo which parameters can be tuned and score measures

#rf_reg.get_params().keys()
#sklearn.metrics.SCORERS.keys()

# %%
search_grid={'n_estimators':[50,100,200],'max_depth':[2,4,6,8,10]}
search=GridSearchCV(estimator=rf_reg,param_grid=search_grid,scoring='neg_mean_absolute_error',n_jobs=1,cv=5, verbose=10)
search.fit(X_train, y_train)
print(search.best_score_)
print(search.best_params_)
# Out:
# Fitting 5 folds for each of 15 candidates, totalling 75 fits
# [CV 1/5; 1/15] START max_depth=2, n_estimators=50...............................
# [CV 1/5; 1/15] END .............max_depth=2, n_estimators=50; total time=   2.6s
# [CV 2/5; 1/15] START max_depth=2, n_estimators=50...............................
# [CV 2/5; 1/15] END .............max_depth=2, n_estimators=50; total time=   2.5s
# [CV 3/5; 1/15] START max_depth=2, n_estimators=50...............................
# [CV 3/5; 1/15] END .............max_depth=2, n_estimators=50; total time=   2.6s
# [CV 4/5; 1/15] START max_depth=2, n_estimators=50...............................
# [CV 4/5; 1/15] END .............max_depth=2, n_estimators=50; total time=   2.5s
# [CV 5/5; 1/15] START max_depth=2, n_estimators=50...............................
# [CV 5/5; 1/15] END .............max_depth=2, n_estimators=50; total time=   2.4s
# [CV 1/5; 2/15] START max_depth=2, n_estimators=100..............................
# [CV 1/5; 2/15] END ............max_depth=2, n_estimators=100; total time=   4.7s
# [CV 2/5; 2/15] START max_depth=2, n_estimators=100..............................
# [CV 2/5; 2/15] END ............max_depth=2, n_estimators=100; total time=   4.7s
# [CV 3/5; 2/15] START max_depth=2, n_estimators=100..............................
# [CV 3/5; 2/15] END ............max_depth=2, n_estimators=100; total time=   4.7s
# [CV 4/5; 2/15] START max_depth=2, n_estimators=100..............................
# [CV 4/5; 2/15] END ............max_depth=2, n_estimators=100; total time=   4.7s
# [CV 5/5; 2/15] START max_depth=2, n_estimators=100..............................
# [CV 5/5; 2/15] END ............max_depth=2, n_estimators=100; total time=   4.7s
# [CV 1/5; 3/15] START max_depth=2, n_estimators=200..............................
# [CV 1/5; 3/15] END ............max_depth=2, n_estimators=200; total time=   9.3s
# [CV 2/5; 3/15] START max_depth=2, n_estimators=200..............................
# [CV 2/5; 3/15] END ............max_depth=2, n_estimators=200; total time=   9.3s
# [CV 3/5; 3/15] START max_depth=2, n_estimators=200..............................
# [CV 3/5; 3/15] END ............max_depth=2, n_estimators=200; total time=   9.3s
# [CV 4/5; 3/15] START max_depth=2, n_estimators=200..............................
# [CV 4/5; 3/15] END ............max_depth=2, n_estimators=200; total time=   9.3s
# [CV 5/5; 3/15] START max_depth=2, n_estimators=200..............................
# [CV 5/5; 3/15] END ............max_depth=2, n_estimators=200; total time=   9.3s
# [CV 1/5; 4/15] START max_depth=4, n_estimators=50...............................
# [CV 1/5; 4/15] END .............max_depth=4, n_estimators=50; total time=   4.5s
# [CV 2/5; 4/15] START max_depth=4, n_estimators=50...............................
# [CV 2/5; 4/15] END .............max_depth=4, n_estimators=50; total time=   4.5s
# [CV 3/5; 4/15] START max_depth=4, n_estimators=50...............................
# [CV 3/5; 4/15] END .............max_depth=4, n_estimators=50; total time=   4.5s
# [CV 4/5; 4/15] START max_depth=4, n_estimators=50...............................
# [CV 4/5; 4/15] END .............max_depth=4, n_estimators=50; total time=   4.5s
# [CV 5/5; 4/15] START max_depth=4, n_estimators=50...............................
# [CV 5/5; 4/15] END .............max_depth=4, n_estimators=50; total time=   4.5s
# [CV 1/5; 5/15] START max_depth=4, n_estimators=100..............................
# [CV 1/5; 5/15] END ............max_depth=4, n_estimators=100; total time=   9.1s
# [CV 2/5; 5/15] START max_depth=4, n_estimators=100..............................
# [CV 2/5; 5/15] END ............max_depth=4, n_estimators=100; total time=   9.1s
# [CV 3/5; 5/15] START max_depth=4, n_estimators=100..............................
# [CV 3/5; 5/15] END ............max_depth=4, n_estimators=100; total time=   9.1s
# [CV 4/5; 5/15] START max_depth=4, n_estimators=100..............................
# [CV 4/5; 5/15] END ............max_depth=4, n_estimators=100; total time=   9.1s
# [CV 5/5; 5/15] START max_depth=4, n_estimators=100..............................
# [CV 5/5; 5/15] END ............max_depth=4, n_estimators=100; total time=   9.1s
# [CV 1/5; 6/15] START max_depth=4, n_estimators=200..............................
# [CV 1/5; 6/15] END ............max_depth=4, n_estimators=200; total time=  18.2s
# [CV 2/5; 6/15] START max_depth=4, n_estimators=200..............................
# [CV 2/5; 6/15] END ............max_depth=4, n_estimators=200; total time=  18.2s
# [CV 3/5; 6/15] START max_depth=4, n_estimators=200..............................
# [CV 3/5; 6/15] END ............max_depth=4, n_estimators=200; total time=  18.2s
# [CV 4/5; 6/15] START max_depth=4, n_estimators=200..............................
# [CV 4/5; 6/15] END ............max_depth=4, n_estimators=200; total time=  18.2s
# [CV 5/5; 6/15] START max_depth=4, n_estimators=200..............................
# [CV 5/5; 6/15] END ............max_depth=4, n_estimators=200; total time=  18.3s
# [CV 1/5; 7/15] START max_depth=6, n_estimators=50...............................
# [CV 1/5; 7/15] END .............max_depth=6, n_estimators=50; total time=   6.7s
# [CV 2/5; 7/15] START max_depth=6, n_estimators=50...............................
# [CV 2/5; 7/15] END .............max_depth=6, n_estimators=50; total time=   6.7s
# [CV 3/5; 7/15] START max_depth=6, n_estimators=50...............................
# [CV 3/5; 7/15] END .............max_depth=6, n_estimators=50; total time=   6.7s
# [CV 4/5; 7/15] START max_depth=6, n_estimators=50...............................
# [CV 4/5; 7/15] END .............max_depth=6, n_estimators=50; total time=   6.7s
# [CV 5/5; 7/15] START max_depth=6, n_estimators=50...............................
# [CV 5/5; 7/15] END .............max_depth=6, n_estimators=50; total time=   6.7s
# [CV 1/5; 8/15] START max_depth=6, n_estimators=100..............................
# [CV 1/5; 8/15] END ............max_depth=6, n_estimators=100; total time=  13.4s
# [CV 2/5; 8/15] START max_depth=6, n_estimators=100..............................
# [CV 2/5; 8/15] END ............max_depth=6, n_estimators=100; total time=  13.4s
# [CV 3/5; 8/15] START max_depth=6, n_estimators=100..............................
# [CV 3/5; 8/15] END ............max_depth=6, n_estimators=100; total time=  14.1s
# [CV 4/5; 8/15] START max_depth=6, n_estimators=100..............................
# [CV 4/5; 8/15] END ............max_depth=6, n_estimators=100; total time=  14.5s
# [CV 5/5; 8/15] START max_depth=6, n_estimators=100..............................
# [CV 5/5; 8/15] END ............max_depth=6, n_estimators=100; total time=  14.1s
# [CV 1/5; 9/15] START max_depth=6, n_estimators=200..............................
# [CV 1/5; 9/15] END ............max_depth=6, n_estimators=200; total time=  26.8s
# [CV 2/5; 9/15] START max_depth=6, n_estimators=200..............................
# [CV 2/5; 9/15] END ............max_depth=6, n_estimators=200; total time=  26.9s
# [CV 3/5; 9/15] START max_depth=6, n_estimators=200..............................
# [CV 3/5; 9/15] END ............max_depth=6, n_estimators=200; total time=  26.4s
# [CV 4/5; 9/15] START max_depth=6, n_estimators=200..............................
# [CV 4/5; 9/15] END ............max_depth=6, n_estimators=200; total time=  26.9s
# [CV 5/5; 9/15] START max_depth=6, n_estimators=200..............................
# [CV 5/5; 9/15] END ............max_depth=6, n_estimators=200; total time=  27.8s
# [CV 1/5; 10/15] START max_depth=8, n_estimators=50..............................
# [CV 1/5; 10/15] END ............max_depth=8, n_estimators=50; total time=  13.7s
# [CV 2/5; 10/15] START max_depth=8, n_estimators=50..............................
# [CV 2/5; 10/15] END ............max_depth=8, n_estimators=50; total time=  16.2s
# [CV 3/5; 10/15] START max_depth=8, n_estimators=50..............................
# [CV 3/5; 10/15] END ............max_depth=8, n_estimators=50; total time=  10.2s
# [CV 4/5; 10/15] START max_depth=8, n_estimators=50..............................
# [CV 4/5; 10/15] END ............max_depth=8, n_estimators=50; total time=   9.3s
# [CV 5/5; 10/15] START max_depth=8, n_estimators=50..............................
# [CV 5/5; 10/15] END ............max_depth=8, n_estimators=50; total time=  10.4s
# [CV 1/5; 11/15] START max_depth=8, n_estimators=100.............................
# [CV 1/5; 11/15] END ...........max_depth=8, n_estimators=100; total time=  22.7s
# [CV 2/5; 11/15] START max_depth=8, n_estimators=100.............................
# [CV 2/5; 11/15] END ...........max_depth=8, n_estimators=100; total time=  20.5s
# [CV 3/5; 11/15] START max_depth=8, n_estimators=100.............................
# [CV 3/5; 11/15] END ...........max_depth=8, n_estimators=100; total time=  19.7s
# [CV 4/5; 11/15] START max_depth=8, n_estimators=100.............................
# [CV 4/5; 11/15] END ...........max_depth=8, n_estimators=100; total time=  20.2s
# [CV 5/5; 11/15] START max_depth=8, n_estimators=100.............................
# [CV 5/5; 11/15] END ...........max_depth=8, n_estimators=100; total time=  19.3s
# [CV 1/5; 12/15] START max_depth=8, n_estimators=200.............................
# [CV 1/5; 12/15] END ...........max_depth=8, n_estimators=200; total time=  43.8s
# [CV 2/5; 12/15] START max_depth=8, n_estimators=200.............................
# [CV 2/5; 12/15] END ...........max_depth=8, n_estimators=200; total time=  38.3s
# [CV 3/5; 12/15] START max_depth=8, n_estimators=200.............................
# [CV 3/5; 12/15] END ...........max_depth=8, n_estimators=200; total time=  40.5s
# [CV 4/5; 12/15] START max_depth=8, n_estimators=200.............................
# [CV 4/5; 12/15] END ...........max_depth=8, n_estimators=200; total time=  39.3s
# [CV 5/5; 12/15] START max_depth=8, n_estimators=200.............................
# [CV 5/5; 12/15] END ...........max_depth=8, n_estimators=200; total time=  39.6s
# [CV 1/5; 13/15] START max_depth=10, n_estimators=50.............................
# [CV 1/5; 13/15] END ...........max_depth=10, n_estimators=50; total time=  11.9s
# [CV 2/5; 13/15] START max_depth=10, n_estimators=50.............................
# [CV 2/5; 13/15] END ...........max_depth=10, n_estimators=50; total time=  12.4s
# [CV 3/5; 13/15] START max_depth=10, n_estimators=50.............................
# [CV 3/5; 13/15] END ...........max_depth=10, n_estimators=50; total time=  12.4s
# [CV 4/5; 13/15] START max_depth=10, n_estimators=50.............................
# [CV 4/5; 13/15] END ...........max_depth=10, n_estimators=50; total time=  12.4s
# [CV 5/5; 13/15] START max_depth=10, n_estimators=50.............................
# [CV 5/5; 13/15] END ...........max_depth=10, n_estimators=50; total time=  11.8s
# [CV 1/5; 14/15] START max_depth=10, n_estimators=100............................
# [CV 1/5; 14/15] END ..........max_depth=10, n_estimators=100; total time=  24.1s
# [CV 2/5; 14/15] START max_depth=10, n_estimators=100............................
# [CV 2/5; 14/15] END ..........max_depth=10, n_estimators=100; total time=  24.3s
# [CV 3/5; 14/15] START max_depth=10, n_estimators=100............................
# [CV 3/5; 14/15] END ..........max_depth=10, n_estimators=100; total time=  23.7s
# [CV 4/5; 14/15] START max_depth=10, n_estimators=100............................
# [CV 4/5; 14/15] END ..........max_depth=10, n_estimators=100; total time=  24.5s
# [CV 5/5; 14/15] START max_depth=10, n_estimators=100............................
# [CV 5/5; 14/15] END ..........max_depth=10, n_estimators=100; total time=  23.4s
# [CV 1/5; 15/15] START max_depth=10, n_estimators=200............................
# [CV 1/5; 15/15] END ..........max_depth=10, n_estimators=200; total time=  48.2s
# [CV 2/5; 15/15] START max_depth=10, n_estimators=200............................
# [CV 2/5; 15/15] END ..........max_depth=10, n_estimators=200; total time=  46.6s
# [CV 3/5; 15/15] START max_depth=10, n_estimators=200............................
# [CV 3/5; 15/15] END ..........max_depth=10, n_estimators=200; total time=  46.2s
# [CV 4/5; 15/15] START max_depth=10, n_estimators=200............................
# [CV 4/5; 15/15] END ..........max_depth=10, n_estimators=200; total time=  47.6s
# [CV 5/5; 15/15] START max_depth=10, n_estimators=200............................
# [CV 5/5; 15/15] END ..........max_depth=10, n_estimators=200; total time=  49.6s
# -2924.0233561601844
# {'max_depth': 10, 'n_estimators': 200}

# %% [markdown]
# ### Fetaure Importance
# What features are the most influential in the model?

# %%
feature_importances = pd.DataFrame(rf_reg.feature_importances_,
    index = X_train.columns,columns=['importance']).sort_values('importance',ascending=False)
feature_importances
# Out:
#                            importance
# latitude                 1.979472e-01
# longitude                1.043419e-01
# Hum_cont                 1.035047e-01
# Temp_cont                7.773041e-02
# Hum_pre_30               6.146159e-02
# Wind_pre_7               6.058846e-02
# Wind_pre_30              4.805534e-02
# Temp_pre_30              4.524614e-02
# Hum_pre_7                4.275188e-02
# Temp_pre_15              4.259794e-02
# Wind_cont                3.889135e-02
# Wind_pre_15              3.560980e-02
# Temp_pre_7               3.164380e-02
# Hum_pre_15               2.237027e-02
# Cause_Lightning          1.980122e-02
# Prec_cont                1.606251e-02
# Prec_pre_7               1.465618e-02
# Prec_pre_15              1.158981e-02
# Prec_pre_30              6.959210e-03
# Vegetation_9             5.985176e-03
# Vegetation_16            2.781893e-03
# Vegetation_4             2.636009e-03
# Cause_Equipment Use      1.999587e-03
# Cause_Missing/Undefined  1.484833e-03
# Vegetation_15            1.264206e-03
# Cause_Powerline          7.757189e-04
# Vegetation_12            5.691886e-04
# Cause_Miscellaneous      3.403303e-04
# Cause_Smoking            2.146781e-04
# Cause_Debris Burning     5.833012e-05
# Cause_Structure          4.362036e-05
# Vegetation_14            2.943742e-05
# Cause_Railroad           6.665189e-06
# Cause_Fireworks          5.585818e-07

# %% [markdown]
# Reevaluate model after deleting least important features

# %%
# selecting features and target variables
X2 = df[['Vegetation_9','Vegetation_16','latitude','Temp_pre_30','Temp_pre_15','Temp_pre_7','Temp_cont','Wind_pre_30','Wind_pre_15','Wind_pre_7','Wind_cont','Hum_pre_30', 'Hum_pre_15','Hum_pre_7','Hum_cont','Prec_pre_30','Prec_pre_15','Prec_pre_7','Prec_cont','Cause_Lightning', 'longitude']]
y2 = y

X_norm = (X-X.min())/(X.max()-X.min())
y_norm = (y-y.min())/(y.max()-y.min())

#train test split
X2_train, X2_test, y2_train, y2_test = train_test_split(X2, y2, test_size=0.2, random_state=42)

# %%
# Random Forest Regressor 
rf_reg = RandomForestRegressor(n_estimators = 200, max_depth=10)

# fit the regressor with x and y data
rf_reg.fit(X2_train, y2_train)

predictions = rf_reg.predict(X2_test)
print('Mean Absolute Error:', metrics.mean_absolute_error(y2_test, predictions))
print('R Squared:', metrics.r2_score(y2_test, predictions))
# Out:
# Mean Absolute Error: 2943.424693693293
# R Squared: 0.14449143867407133

# %% [markdown]
# ### Neural network model

# %%
X_train.shape
# Out:
# (30951, 34)

# %%
normalizer = tf.keras.layers.Normalization(axis=-1)
normalizer.adapt(np.array(X_train))

# %%
model = Sequential([
    normalizer,
    Dense(21, activation="relu", kernel_initializer='normal',input_dim = X_train.shape[1]),
    Dense(20, activation="relu"),
    Dense(15, activation="relu"),
    Dense(1, activation='linear')
])

model.compile(
    optimizer='adam',
    loss='mean_squared_error',
    metrics=['accuracy','mae']
)

kernel_regularizer = regularizers.l2(0.1)
#checkpoint_name = 'Weights-{epoch:03d}--{val_loss:.5f}.hdf5' 
#checkpoint = ModelCheckpoint(checkpoint_name, monitor='val_loss', verbose = 1, save_best_only = True, mode ='auto')

# %%
history = model.fit(
    X_train,
    y_train,
    epochs=200,
    validation_split=0.15,
    callbacks=[tf.keras.callbacks.EarlyStopping(
        monitor='val_mae',
        patience=30,
        mode='min',
        restore_best_weights=True
    )]
)
# Out:
# Epoch 1/200
# 823/823 [==============================] - 1s 1ms/step - loss: 226401872.0000 - accuracy: 0.0025 - mae: 2544.3872 - val_loss: 216905712.0000 - val_accuracy: 0.0017 - val_mae: 3289.9146
# Epoch 2/200
200
# 823/823 [==============================] - 1s 1ms/step - loss: 196148832.0000 - accuracy: 0.0027 - mae: 2797.0725 - val_loss: 206509392.0000 - val_accuracy: 0.0017 - val_mae: 2856.5576
# Epoch 149/200
# 823/823 [==============================] - 1s 1ms/step - loss: 196010944.0000 - accuracy: 0.0027 - mae: 2755.5710 - val_loss: 206379424.0000 - val_accuracy: 0.0017 - val_mae: 3060.5576
# Epoch 150/200
# 823/823 [==============================] - 1s 1ms/step - loss: 196176656.0000 - accuracy: 0.0027 - mae: 2808.8792 - val_loss: 206234528.0000 - val_accuracy: 0.0017 - val_mae: 2951.8152
# Epoch 151/200
# 823/823 [==============================] - 1s 1ms/step - loss: 195991520.0000 - accuracy: 0.0027 - mae: 2750.3682 - val_loss: 205946176.0000 - val_accuracy: 0.0017 - val_mae: 2999.0989
# Epoch 152/200
# 823/823 [==============================] - 1s 1ms/step - loss: 196003920.0000 - accuracy: 0.0027 - mae: 2768.8083 - val_loss: 206221520.0000 - val_accuracy: 0.0017 - val_mae: 3038.3579
# Epoch 153/200
# 823/823 [==============================] - 1s 1ms/step - loss: 195607856.0000 - accuracy: 0.0027 - mae: 2779.5203 - val_loss: 205324352.0000 - val_accuracy: 0.0017 - val_mae: 2978.6299
# Epoch 154/200
# 823/823 [==============================] - 1s 1ms/step - loss: 195838336.0000 - accuracy: 0.0027 - mae: 2778.6504 - val_loss: 205822512.0000 - val_accuracy: 0.0017 - val_mae: 2987.7048
# Epoch 155/200
# 823/823 [==============================] - 1s 1ms/step - loss: 195555632.0000 - accuracy: 0.0027 - mae: 2790.5110 - val_loss: 206831008.0000 - val_accuracy: 0.0017 - val_mae: 2887.7180

# %%
test_loss, test_acc, test_mae = model.evaluate(x=X_test, y=y_test, verbose=0)
print('Mean Absolute Error: {acc:0.3f}'.format(acc=test_mae))
print('accuracy: {acc:0.3f}'.format(acc=test_acc))
print('loss: {acc:0.3f}'.format(acc=test_loss))
# Out:
# Mean Absolute Error: 2707.866
# accuracy: 0.002
# loss: 211382272.000

# %%
historydf = pd.DataFrame(history.history)

# %%
#Run this cell to plot the epoch vs loss graph
plt.figure(figsize=(10, 5))
plt.plot(historydf['loss'])
plt.plot(historydf['val_loss'])
plt.title('Loss vs. epochs')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper right')
plt.show()

# %%
#Run this cell to plot the epoch vs loss graph
plt.figure(figsize=(10, 5))
plt.plot(historydf['accuracy'],label='accuracy')
plt.plot(historydf['val_accuracy'],label='val_accuracy')
plt.title('Accuracy vs. epochs')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper right')
plt.show()

# %%
#Run this cell to plot the epoch vs loss graph
plt.figure(figsize=(10, 5))
plt.plot(historydf['mae'],label='mae')
plt.plot(historydf['val_mae'],label='val_mae')
plt.title('MAE vs. epochs')
plt.ylabel('MAE')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# ## Other

# %%
#XGBModel.get_params().keys()

#search_grid={'n_estimators':[10,50,100,250]}
#searchxgb=GridSearchCV(estimator=XGBModel,param_grid=search_grid,scoring='r2',n_jobs=1,cv=3)
#searchxgb.fit(X_train, y_train)
#print(searchxgb.best_score_)
#print(searchxgb.best_params_)

# %%
#PCA Analysis
X_scaled = StandardScaler().fit_transform(X_train)

pca = PCA(n_components=5)
principalComponents = pca.fit_transform(X_scaled)
principalDf = pd.DataFrame(data = principalComponents
             , columns = ['pc1', 'pc2','pc3','pc4','pc5'])

X_pcca = principalDf[['pc1','pc2','pc3','pc4','pc5']]

# %% [markdown]
# ## Weather data

# %%
# Get weather stations ordered by distance to Vancouver, BC
stations = Stations(lat = 38.843988, lon = -122.759707, daily = datetime(2018, 1, 1))
# Fetch closest station (limit = 1)
station = stations.fetch(1)

data = Daily(station, start = datetime(2018, 1, 1), end = datetime(2018, 1, 1))
# Fetch Pandas DataFrame
data = data.fetch()

data.plot(y=['tavg', 'tmin', 'tmax'])
