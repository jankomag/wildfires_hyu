# %%
import pandas as pd
import matplotlib.pyplot as plt
import missingno as msno
import numpy as np

# %%
df = pd.read_csv('Wildfire.csv')
df = df.drop(columns=['Unnamed: 0', 'Unnamed: 0.1','disc_date_final','cont_date_final','cont_clean_date','putout_time'])
df['disc_clean_date'] = pd.to_datetime(df['disc_clean_date'], format='%m/%d/%Y')
df.columns
# Out:
# Index(['fire_name', 'fire_size', 'fire_size_class', 'stat_cause_descr',
#        'latitude', 'longitude', 'state', 'disc_clean_date', 'discovery_month',
#        'disc_date_pre', 'disc_pre_year', 'disc_pre_month', 'wstation_usaf',
#        'dstation_m', 'wstation_wban', 'wstation_byear', 'wstation_eyear',
#        'Vegetation', 'fire_mag', 'weather_file', 'Temp_pre_30', 'Temp_pre_15',
#        'Temp_pre_7', 'Temp_cont', 'Wind_pre_30', 'Wind_pre_15', 'Wind_pre_7',
#        'Wind_cont', 'Hum_pre_30', 'Hum_pre_15', 'Hum_pre_7', 'Hum_cont',
#        'Prec_pre_30', 'Prec_pre_15', 'Prec_pre_7', 'Prec_cont', 'remoteness'],
#       dtype='object')

# %%
df
# Out:
#       fire_name  fire_size fire_size_class   stat_cause_descr   latitude  \
# 0           NaN       10.0               C  Missing/Undefined  18.105072
# 1           NaN        3.0               B              Arson  35.038330
# 2           NaN       60.0               C              Arson  34.947800
# 3        WNA  1        1.0               B     Debris Burning  39.641400
# 4           NaN        2.0               B      Miscellaneous  30.700600
# ...         ...        ...             ...                ...        ...
# 55362    IMPACT     6289.0               G  Missing/Undefined  39.180000
# 55363     BUTTE    70868.0               G  Missing/Undefined  38.342719
# 55364    WILLOW     5702.0               G              Arson  37.262607
# 55365    BARKER     3261.0               F      Miscellaneous  40.604300
# 55366    VALLEY    76067.0               G  Missing/Undefined  38.843988
#
#         longitude state disc_clean_date discovery_month disc_date_pre  ...  \
# ...

# %%
print(f"Average Fire Size: {df.fire_size.mean()}")
print(f"Standard Deviation of Fire Size: {df.fire_size.std()}")
print(f"Median of Fire Size: {df.fire_size.median()}")
# Out:
# Average Fire Size: 2104.645160894757
# Standard Deviation of Fire Size: 14777.005363893695
# Median of Fire Size: 4.0

# %%
plt.hist(df['fire_size'], density=True)
# Out:
# (array([0.08222527, 0.00828431, 0.00391263, 0.00142862, 0.00178471,
#         0.00135569, 0.00084516, 0.00065854, 0.00073362, 0.0003046 ]),
#  array([ 0.51 , 10.359, 20.208, 30.057, 39.906, 49.755, 59.604, 69.453,
#         79.302, 89.151, 99.   ]),
#  <BarContainer object of 10 artists>)

# %%
msno.matrix(df)
# Out:
# <AxesSubplot:>

# %%
df = df.replace({'NaN':np.nan, 'NaN':np.nan})

# %%
df.head(10)
# Out:
#   fire_name  fire_size fire_size_class   stat_cause_descr   latitude  \
# 0       NaN       10.0               C  Missing/Undefined  18.105072
# 1       NaN        3.0               B              Arson  35.038330
# 2       NaN       60.0               C              Arson  34.947800
# 3    WNA  1        1.0               B     Debris Burning  39.641400
# 4       NaN        2.0               B      Miscellaneous  30.700600
# 5       NaN        1.0               B     Debris Burning  32.063900
# 6       NaN        5.2               B     Debris Burning  31.316978
# 7       NaN        1.0               B           Campfire  30.904720
# 8       NaN        1.0               B              Arson  35.900310
# 9     CRAZY        1.0               B      Miscellaneous  48.839400
#
#     longitude state disc_clean_date discovery_month disc_date_pre  ...  \
# 0  -66.753044    PR      2007-02-11             Feb     1/12/2007  ...
# ...

# %%
df = df.loc[df['fire_size'] < 5000]
df
# Out:
#                fire_name  fire_size fire_size_class   stat_cause_descr  \
# 0                    NaN       10.0               C  Missing/Undefined
# 1                    NaN        3.0               B              Arson
# 2                    NaN       60.0               C              Arson
# 3                 WNA  1        1.0               B     Debris Burning
# 4                    NaN        2.0               B      Miscellaneous
# ...                  ...        ...             ...                ...
# 55356            SA HILL     4336.0               F          Lightning
# 55357  WF FEE TITLE 2015     4856.0               F          Lightning
# 55359            50TH ST     3500.0               F  Missing/Undefined
# 55360      LILLIAM RANCH     3500.0               F  Missing/Undefined
# 55365             BARKER     3261.0               F      Miscellaneous
#
#         latitude   longitude state disc_clean_date discovery_month  \
# ...

# %%
plt.hist(df['fire_size'], density=True)
# Out:
# (array([0.08222527, 0.00828431, 0.00391263, 0.00142862, 0.00178471,
#         0.00135569, 0.00084516, 0.00065854, 0.00073362, 0.0003046 ]),
#  array([ 0.51 , 10.359, 20.208, 30.057, 39.906, 49.755, 59.604, 69.453,
#         79.302, 89.151, 99.   ]),
#  <BarContainer object of 10 artists>)

# %%
df
# Out:
#            fire_name  fire_size fire_size_class   stat_cause_descr   latitude  \
# 0                NaN       10.0               C  Missing/Undefined  18.105072
# 1                NaN        3.0               B              Arson  35.038330
# 2                NaN       60.0               C              Arson  34.947800
# 3             WNA  1        1.0               B     Debris Burning  39.641400
# 4                NaN        2.0               B      Miscellaneous  30.700600
# ...              ...        ...             ...                ...        ...
# 55359        50TH ST     3500.0               F  Missing/Undefined  37.678611
# 55360  LILLIAM RANCH     3500.0               F  Missing/Undefined  37.606667
# 55362         IMPACT     6289.0               G  Missing/Undefined  39.180000
# 55364         WILLOW     5702.0               G              Arson  37.262607
# 55365         BARKER     3261.0               F      Miscellaneous  40.604300
#
# ...
